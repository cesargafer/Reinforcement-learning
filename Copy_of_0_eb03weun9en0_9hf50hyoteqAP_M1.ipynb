# %% [markdown]
# <a href="https://colab.research.google.com/github/cesargafer/Reinforcement-learning/blob/main/Copy_of_0_eb03weun9en0_9hf50hyoteqAP_M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Misión 1: Explorando los picos y valles del mercado bursátil

# %% [markdown]
# ## Ejercicio 1

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
import pandas as pd
import datetime as dt
import pandas_datareader.data as data_reader

# %%
# !pip install alpha_vantage
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
from datetime import datetime

# Importar el módulo json
import json



# API key de Alpha Vantage
api_key = 'KOV4S8MT1CZK6MB5'  # Reemplaza 'tu_api_key' con tu propia API key de Alpha Vantage

# Crear una instancia de TimeSeries con la API key
ts = TimeSeries(api_key)

# Definir el símbolo de la compañía
symbol = 'AAPL'

# Obtener los datos diarios de precios de las acciones
data, meta_data = ts.get_daily(symbol=symbol, outputsize='full')
# Convertir los datos JSON en un diccionario de Python

data_dict = json.loads(json.dumps(data))
print(data_dict)

# Convertir los datos a un DataFrame de pandas
df = pd.DataFrame.from_dict(data_dict, orient='index')
print (df)
df.index = pd.to_datetime(df.index)

# Filtrar los datos por rango de fechas
start_date = datetime(2020, 1, 1)
end_date = datetime(2022, 9, 30)

filtered_df = df[start_date:end_date]

# Mostrar los datos filtrados y metadatos obtenidos
print(filtered_df)
print(meta_data)
# Out:
# ...
# {'2024-04-12': {'1. open': '174.2600', '2. high': '178.3600', '3. low': '174.2100', '4. close': '176.5500', '5. volume': '101670886'}, '2024-04-11': {'1. open': '168.3400', '2. high': '175.4600', '3. low': '168.1600', '4. close': '175.0400', '5. volume': '91070275'}, '2024-04-10': {'1. open': '168.8000', '2. high': '169.0900', '3. low': '167.1100', '4. close': '167.7800', '5. volume': '49709336'}, '2024-04-09': {'1. open': '168.7000', '2. high': '170.0800', '3. low': '168.3500', '4. close': '169.6700', '5. volume': '42231444'}, '2024-04-08': {'1. open': '169.0300', '2. high': '169.2000', '3. low': '168.2400', '4. close': '168.4500', '5. volume': '37216858'}, '2024-04-05': {'1. open': '169.5900', '2. high': '170.3900', '3. low': '168.9500', '4. close': '169.5800', '5. volume': '41975776'}, '2024-04-04': {'1. open': '170.2900', '2. high': '171.9200', '3. low': '168.8200', '4. close': '168.8200', '5. volume': '53355055'}, '2024-04-03': {'1. open': '168.7900', '2. high': '170.6800', '3. 
# ...

# %%
# !pip install alpha_vantage
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
from datetime import datetime

# API key de Alpha Vantage
api_key = 'KOV4S8MT1CZK6MB5'  # Reemplaza 'tu_api_key' con tu propia API key de Alpha Vantage

# Crear una instancia de TimeSeries con la API key
ts = TimeSeries(api_key)

# Definir el símbolo de la compañía
symbol = 'AAPL'

# Obtener los datos diarios de precios de las acciones
data, meta_data = ts.get_daily(symbol=symbol, outputsize='full')

# Convertir los datos a un DataFrame de pandas
df = pd.DataFrame.from_dict(data, orient='index')
df.index = pd.to_datetime(df.index)

# Filtrar los datos por rango de fechas
start_date = datetime(2020, 1, 1)
end_date = datetime(2022, 9, 30)

filtered_df = df[(df.index >= start_date) & (df.index <= end_date)]

# Mostrar el DataFrame filtrado
print(filtered_df)
# Out:
# ...
#              1. open   2. high    3. low  4. close  5. volume
# 2022-09-30  141.2800  143.1000  138.0000  138.2000  124925274
# 2022-09-29  146.1000  146.7200  140.6800  142.4800  128138237
# 2022-09-28  147.6400  150.6414  144.8400  149.8400  146691387
# 2022-09-27  152.7400  154.7200  149.9450  151.7600   84442741
# 2022-09-26  149.6600  153.7701  149.6400  150.7700   93339409
# ...              ...       ...       ...       ...        ...
# 2020-01-08  297.1600  304.4400  297.1600  303.1900   33090946
# 2020-01-07  299.8400  300.9000  297.4800  298.3900   27877655
# 2020-01-06  293.7900  299.9600  292.7500  299.8000   29644644
# 2020-01-03  297.1500  300.5800  296.5000  297.4300   36633878
# 2020-01-02  296.2400  300.6000  295.1900  300.3500   33911864
#
# [693 rows x 5 columns]

# %% [markdown]
# ## Ejercicio 2

# %%
# !pip install alpha_vantage
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
from datetime import datetime

# Importar el módulo json
import json



# API key de Alpha Vantage
api_key = 'KOV4S8MT1CZK6MB5'  # Reemplaza 'tu_api_key' con tu propia API key de Alpha Vantage

# Crear una instancia de TimeSeries con la API key
ts = TimeSeries(api_key)

# Definir el símbolo de la compañía
symbol = 'GOOGL'

# Obtener los datos diarios de precios de las acciones
data, meta_data = ts.get_daily(symbol=symbol, outputsize='full')
# Convertir los datos JSON en un diccionario de Python

data_dict = json.loads(json.dumps(data))
print(data_dict)

# Convertir los datos a un DataFrame de pandas
df = pd.DataFrame.from_dict(data_dict, orient='index')
print (df)
df.index = pd.to_datetime(df)

# Filtrar los datos por rango de fechas
start_date = datetime(2020, 1, 1)
end_date = datetime(2022, 9, 30)

filtered_df = df.loc[start_date:end_date]

# Mostrar los datos filtrados y metadatos obtenidos
print(filtered_df)
print(meta_data)
# Out:
# ...
# {'2024-04-12': {'1. open': '157.9600', '2. high': '160.2225', '3. low': '157.1400', '4. close': '157.7300', '5. volume': '25353746'}, '2024-04-11': {'1. open': '156.9100', '2. high': '159.6800', '3. low': '156.4600', '4. close': '159.4100', '5. volume': '27166431'}, '2024-04-10': {'1. open': '156.2100', '2. high': '156.6100', '3. low': '154.6800', '4. close': '156.1400', '5. volume': '22838629'}, '2024-04-09': {'1. open': '156.0850', '2. high': '158.5600', '3. low': '155.1900', '4. close': '156.6000', '5. volume': '30739691'}, '2024-04-08': {'1. open': '152.7800', '2. high': '155.2700', '3. low': '152.6100', '4. close': '154.8500', '5. volume': '20577435'}, '2024-04-05': {'1. open': '150.0300', '2. high': '153.4200', '3. low': '149.6000', '4. close': '152.5000', '5. volume': '23328522'}, '2024-04-04': {'1. open': '153.5000', '2. high': '154.7700', '3. low': '150.4500', '4. close': '150.5300', '5. volume': '34468227'}, '2024-04-03': {'1. open': '153.6000', '2. high': '155.0800', '3. l
# ...

# %%
dataset = data_reader.DataReader("GOOGL", data_source="yahoo", start="01/01/20")
dataset
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02   68.433998   67.324501   67.420502   68.433998  27278000.0
# 2020-01-03   68.687500   67.365997   67.400002   68.075996  23408000.0
# 2020-01-06   69.916000   67.550003   67.581497   69.890503  46768000.0
# 2020-01-07   70.175003   69.578003   70.023003   69.755501  34330000.0
# 2020-01-08   70.592499   69.631500   69.740997   70.251999  35314000.0
# ...                ...         ...         ...         ...         ...
# 2022-09-06  108.029999  105.779999  107.300003  106.809998  25068300.0
# 2022-09-07  109.980003  106.900002  107.059998  109.449997  23167000.0
# 2022-09-08  109.599998  107.160004  108.040001  108.379997  24238300.0
# 2022-09-09  110.989998  109.019997  109.070000  110.650002  23197700.0
# 2022-09-12  111.620003  109.930000  110.989998  110.860001  22933300.0
#
#              Adj Close
# Date
# 2020-01-02   68.433998
# 2020-01-03   68.075996
# 2020-01-06   69.890503
# ...

# %%
df.describe()
# Out:
#          1. open    2. high    3. low  4. close 5. volume
# count       4946       4946      4946      4946      4946
# unique      4748       4745      4794      4820      4918
# top     544.0000  1135.0000  545.5000  583.0000   3962000
# freq           3          3         3         4         2

# %%
# !pip install plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
import plotly.graph_objects as go

# Suponiendo que `df` es el DataFrame de pandas que deseas visualizar

fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=df.index, y=df['1. open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=df.index, y=df['4. close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="AAPL from Alpha Vantage",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(size=16, color="Black"))

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Suponiendo que `df` es el DataFrame de pandas que deseas visualizar

fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=filtered_df.index, y=df['1. open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=filtered_df.index, y=df['4. close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="AAPL from Alpha Vantage",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(size=16, color="Black"))

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=filtered_df.index, y=filtered_df['1. open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=filtered_df.index, y=filtered_df['4. close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="AAPL from Alpha Vantage", xaxis_title="Date", yaxis_title="Value, $",
    legend_title="Column", font=dict(size=16, color="Black"))
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=dataset.index, y=dataset['Open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=dataset.index, y=dataset['Close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="GOOGL from Yahoo!", xaxis_title="Date", yaxis_title="Value, $",
    legend_title="Column", font=dict(size=16, color="Black"))
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Suponiendo que `df` es el DataFrame de pandas que deseas visualizar

fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=df.index, y=df['1. open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=df.index, y=df['4. close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="GOOGL from Alpha Vantage",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(size=16, color="Black"))

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from datetime import datetime, timedelta
start_date = datetime.now() - timedelta(days=200)
print("Starting date: ", start_date.strftime("%m/%d/%y"))
data_reader.DataReader("GOOGL", data_source="yahoo", start=start_date.strftime("%m/%d/%y"))
# Out:
# Starting date:  02/25/22
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-02-25  135.271500  131.751495  133.552002  134.459503  36406000.0
# 2022-02-28  135.751495  132.592499  133.050003  135.057007  38864000.0
# 2022-03-01  136.255493  133.218506  134.878494  134.061493  26496000.0
# 2022-03-02  135.262497  133.071503  134.628006  134.571503  23520000.0
# 2022-03-03  136.439499  133.025497  136.009995  133.899506  24604000.0
# ...                ...         ...         ...         ...         ...
# 2022-09-06  108.029999  105.779999  107.300003  106.809998  25068300.0
# 2022-09-07  109.980003  106.900002  107.059998  109.449997  23167000.0
# 2022-09-08  109.599998  107.160004  108.040001  108.379997  24238300.0
# 2022-09-09  110.989998  109.019997  109.070000  110.650002  23197700.0
# 2022-09-12  111.620003  109.930000  110.989998  110.860001  22933300.0
#
#              Adj Close
# Date
# 2022-02-25  134.459503
# 2022-02-28  135.057007
# ...

# %%
dataset = dataset.iloc[-200:]
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=dataset.index, y=dataset['Open'], mode='lines', name="Open"))
fig1.add_trace(go.Scatter(
    x=dataset.index, y=dataset['Close'], mode='markers', name="Close", opacity=0.5))

fig1.update_layout(
    title="GOOGL from Yahoo!", xaxis_title="Date", yaxis_title="Value, $",
    legend_title="Column", font=dict(size=16, color="Black"))
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-11-24  146.249496  144.373001  145.473495  146.119995  18040000.0
# 2021-11-26  144.557495  141.842499  144.348495  142.182999  30470000.0
# 2021-11-29  146.297501  143.893494  144.000000  145.530502  32596000.0
# 2021-11-30  146.000000  141.601501  145.008499  141.897507  42068000.0
# 2021-12-01  145.950500  140.912003  144.000000  141.051498  34020000.0
# ...                ...         ...         ...         ...         ...
# 2022-09-06  108.029999  105.779999  107.300003  106.809998  25068300.0
# 2022-09-07  109.980003  106.900002  107.059998  109.449997  23167000.0
# 2022-09-08  109.599998  107.160004  108.040001  108.379997  24238300.0
# 2022-09-09  110.989998  109.019997  109.070000  110.650002  23197700.0
# 2022-09-12  111.620003  109.930000  110.989998  110.860001  22933300.0
#
#              Adj Close
# Date
# 2021-11-24  146.119995
# 2021-11-26  142.182999
# 2021-11-29  145.530502
# ...

# %% [markdown]
# ## Ejercicio 3

# %%
def dataset_loader(stock_name, clip_data, train_portion=0.5):
    full_dataset = data_reader.DataReader(
        stock_name, data_source="yahoo").iloc[-clip_data:]

    data = full_dataset['Close']
    data_samples = len(data)
    data_mid_date = str(full_dataset.index[int(data_samples * train_portion)])

    train_data = data[:data_mid_date]
    test_data = data[data_mid_date:]

    data_start_date = str(full_dataset.index[0])
    data_end_date = str(full_dataset.index[-1])
    fmt_str = "{} <---[{}]---> {} <---[{}]---> {}"
    print("Timeline:\n", fmt_str.format(
        data_start_date.split()[0], len(train_data),
        data_mid_date.split()[0], len(test_data),
        data_end_date.split()[0]))

    return train_data, test_data

# %%
df = filtered_df.sort_index()
print(df.index)
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22',
#                '2022-09-23', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', length=693, freq=None)

# %%
def dataset_loader(df, clip_data, train_portion=0.5):
    # Seleccionar los últimos clip_data registros del DataFrame
    full_dataset = df.iloc[-clip_data:]

    # Seleccionar solo los precios de cierre de las acciones
    data = full_dataset['4. close']

    # Calcular el número de muestras de datos y la fecha media
    data_samples = len(data)
    data_mid_date = str(full_dataset.index[int(data_samples * train_portion)])

    # Dividir los datos en conjunto de entrenamiento y conjunto de prueba
    train_data = data[:data_mid_date]
    test_data = data[data_mid_date:]

    # Obtener las fechas de inicio y fin del conjunto de datos completo
    data_start_date = str(full_dataset.index[0])
    data_end_date = str(full_dataset.index[-1])

    # Imprimir la línea de tiempo para los datos
    fmt_str = "{} <---[{}]---> {} <---[{}]---> {}"
    print("Timeline:\n", fmt_str.format(
        data_start_date.split()[0], len(train_data),
        data_mid_date.split()[0], len(test_data),
        data_end_date.split()[0]))

    # Devolver los conjuntos de datos de entrenamiento y prueba
    return train_data, test_data

# %%
train_data, test_data = dataset_loader(
    stock_name="AAPL", clip_data=200, train_portion=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-ae169765f5d4> in <cell line: 1>()
# ----> 1 train_data, test_data = dataset_loader(
#       2     stock_name="AAPL", clip_data=200, train_portion=0.5)
#
# TypeError: dataset_loader() got an unexpected keyword argument 'stock_name'

# %%
train_data, test_data = dataset_loader(
    df=df, clip_data=200, train_portion=0.5)
# Out:
# Timeline:
#  2021-12-15 <---[101]---> 2022-05-10 <---[100]---> 2022-09-30

# %%
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=train_data.index, y=train_data, mode='lines', name="Train"))
fig1.add_trace(go.Scatter(
    x=test_data.index, y=test_data, mode='lines', name="Test"))

fig1.update_layout(
    title="AAPL from Yahoo!",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(
        size=16,
        color="Black"
    )
)

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=train_data.index, y=train_data, mode='lines', name="Train"))
fig1.add_trace(go.Scatter(
    x=test_data.index, y=test_data, mode='lines', name="Test"))

fig1.update_layout(
    title="AAPL from Alpha Vantage",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(
        size=16,
        color="Black"
    )
)

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
train_data, test_data = dataset_loader(
    stock_name="BTC-USD", clip_data=500, train_portion=0.5)
# Out:
# Timeline:
#  2021-05-02 <---[251]---> 2022-01-07 <---[250]---> 2022-09-13

# %%
fig1 = go.Figure()

fig1.add_trace(go.Scatter(
    x=train_data.index, y=train_data, mode='lines', name="Train"))
fig1.add_trace(go.Scatter(
    x=test_data.index, y=test_data, mode='lines', name="Test"))

fig1.update_layout(
    title="BTC-USD from Yahoo!",
    xaxis_title="Date",
    yaxis_title="Value, $",
    legend_title="Column",
    font=dict(
        size=16,
        color="Black"
    )
)

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
